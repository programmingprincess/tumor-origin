# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Pandas for reading 
import pandas as pd

# Helper libraries
import numpy as np

print(tf.__version__)
# Out:
# 1.4.0

# %%
mir = pd.read_csv("88ef0233-d4f6-43ee-aa5f-2bb5089072d5.mirbase21.isoforms.quantification.txt", sep='\t')
for index, row in mir.iterrows():
    region = row['miRNA_region'].split(",")
    if(len(region) > 1):
        region = region[1]
    else:
        region = region[0]
    row['feature_name'] = row['miRNA_ID'] + "_" + region

#print(mir['feature'])
# Out:
# hsa-let-7a-1_precursor
# hsa-let-7a-1_precursor
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0000062
# hsa-let-7a-1_MIMAT0004481
# hsa-let-7a-1_MIMAT0004481
# hsa-let-7a-1_MIMAT0004481
# hsa-let-7a-1_MIMAT0004481
# hsa-let-7a-1_MIMAT0004481
# hsa-let-7a-2_MIMAT0010195
# hsa-let-7a-2_MIMAT0010195
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-2_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# hsa-let-7a-3_MIMAT0000062
# ...

# %%
print (mir.count)
# Out:
# <bound method DataFrame.count of           miRNA_ID                    isoform_coords  read_count  \
# 0     hsa-let-7a-1     hg38:chr9:94175939-94175962:+           1
# 1     hsa-let-7a-1     hg38:chr9:94175942-94175962:+           1
# 2     hsa-let-7a-1     hg38:chr9:94175961-94175984:+           2
# 3     hsa-let-7a-1     hg38:chr9:94175962-94175981:+          45
# 4     hsa-let-7a-1     hg38:chr9:94175962-94175982:+        1446
# 5     hsa-let-7a-1     hg38:chr9:94175962-94175983:+        2136
# 6     hsa-let-7a-1     hg38:chr9:94175962-94175984:+        5404
# 7     hsa-let-7a-1     hg38:chr9:94175962-94175985:+         194
# 8     hsa-let-7a-1     hg38:chr9:94175962-94175986:+           4
# 9     hsa-let-7a-1     hg38:chr9:94175963-94175984:+           1
# 10    hsa-let-7a-1     hg38:chr9:94175963-94175985:+           1
# 11    hsa-let-7a-1     hg38:chr9:94175965-94175982:+           1
# 12    hsa-let-7a-1     hg38:chr9:94175965-94175984:+           1
# ...

# %%
print(mir['feature_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'feature_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-e35b80f22fcd> in <module>
# ----> 1 print(mir['feature_name'])
#
# ...
